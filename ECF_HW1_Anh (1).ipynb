# %%
import pandas as pd
import numpy as np

# %%
path ='/content/data5.xls'

# %%
data = pd.read_excel(path)
data.head(5)
# Out:
#   ticker  year  meanagef  ...  NonFounderFamily     ln(Q)  ln(Asset)
# 0  9441B  1992       NaN  ...                 0  0.444055   8.579492
# 1  9441B  1993       NaN  ...                 0  0.442869   8.261449
# 2     AA  1992      95.0  ...                 0  0.211180   9.307748
# 3     AA  1993      95.0  ...                 0  0.202430   9.358493
# 4     AA  1994      95.0  ...                 0  0.268021   9.421670
#
# [5 rows x 15 columns]

# %%
pip install tabulate

# %%
data.describe()
# Out:
#               year     meanagef  ...        ln(Q)    ln(Asset)
# count  2472.000000  1466.000000  ...  2472.000000  2472.000000
# mean   1995.991100    90.417519  ...     0.574723     3.640432
# std       2.539833    11.728663  ...     0.472395     0.649263
# min    1992.000000    39.000000  ...    -0.264819     2.302585
# 25%    1994.000000    95.000000  ...     0.221486     3.332205
# 50%    1996.000000    95.000000  ...     0.457563     3.583519
# 75%    1998.000000    95.000000  ...     0.837096     3.951244
# max    2001.000000    95.000000  ...     2.779245     9.767811
#
# [8 rows x 14 columns]

# %%
data.replace(np.nan, 0)
# Out:
#      ticker  year  meanagef  ...  NonFounderFamily     ln(Q)  ln(Asset)
# 0     9441B  1992       0.0  ...                 0  0.444055   8.579492
# 1     9441B  1993       0.0  ...                 0  0.442869   8.261449
# 2        AA  1992      95.0  ...                 0  0.211180   9.307748
# 3        AA  1993      95.0  ...                 0  0.202430   9.358493
# 4        AA  1994      95.0  ...                 0  0.268021   9.421670
# ...     ...   ...       ...  ...               ...       ...        ...
# 2467      Z  1995      95.0  ...                 0  0.073613   4.025352
# 2468      Z  1996      95.0  ...                 0  0.337870   4.025352
# 2469      Z  1997      95.0  ...                 0  0.420839   4.025352
# 2470      Z  1998      95.0  ...                 0 -0.134477   4.025352
# 2471      Z  1999      95.0  ...                 0 -0.133356   4.025352
#
# [2472 rows x 15 columns]

# %%
data['digit2_in'].describe()
# Out:
# count    2472.000000
# mean       39.563916
# std        16.173206
# min        10.000000
# 25%        28.000000
# 50%        36.000000
# 75%        51.000000
# max        87.000000
# Name: digit2_in, dtype: float64

# %%
#col1 = data.groupby(data['digit2_in'])['founderCEO'].count()
#col1
Number_of_founder_CEO= data.groupby(data['digit2_in'])['founderCEO'].sum()
Number_of_founder_CEO
#Percent_Family_Firms_in_Industry = total1/col1*100

#data['family_firm'] = total1
#data['Percent_Family_Firms_in_Industry'] = Percent_Family_Firms_in_Industry
# Out:
# digit2_in
# 10     0
# 13     0
# 15     1
# 16     0
# 20     0
# 21     0
# 22     0
# 23     3
# 24     0
# 25     0
# 26     3
# 27     0
# 28     0
# 29     3
# 30    18
# 31     0
# 32     0
# 33     9
# 34     0
# 35    17
# 36    16
# 37     5
# 38    15
# 39     0
# 40     0
# 42     0
# 45     9
# 48     8
# 49     5
# 50     0
# 51     0
# 52     9
# 53     5
# 54     0
# 55     0
# 56    15
# 57     0
# 58     0
# 59     4
# 60     0
# 61     0
# 62     0
# 63     4
# 64     0
# 70     0
# 72     8
# 73    27
# 75     0
# 78     0
# 79     0
# 80     0
# 87     0
# Name: founderCEO, dtype: int64

# %%
#col2 = data.groupby(data['digit2_in'])['NonFounderFamily'].count()
Number_of_Non_founder_CEO =data.groupby(data['digit2_in'])['NonFounderFamily'].sum()
Number_of_Non_founder_CEO
#Percent_Non_Family_Firms_in_Industry = total2/col2*100
#Percent_Non_Family_Firms_in_Industry

#data['non_family_firm'] = total2
#data['Percent_Non_Family_Firms_in_Industry'] = Percent_Non_Family_Firms_in_Industry
# Out:
# digit2_in
# 10     0
# 13     0
# 15     9
# 16     0
# 20    69
# 21     0
# 22    10
# 23    10
# 24    16
# 25     0
# 26    28
# 27    67
# 28    76
# 29    14
# 30    14
# 31     0
# 32     0
# 33    26
# 34    26
# 35    58
# 36    24
# 37    48
# 38    17
# 39    10
# 40     0
# 42     7
# 45     0
# 48    14
# 49     0
# 50    10
# 51     8
# 52     0
# 53    15
# 54    29
# 55     8
# 56    26
# 57     0
# 58     5
# 59    31
# 60    10
# 61     0
# 62     0
# 63    24
# 64     0
# 70    16
# 72    12
# 73    10
# 75     0
# 78     6
# 79     0
# 80     0
# 87     0
# Name: NonFounderFamily, dtype: int64

# %%
Total = Number_of_founder_CEO + Number_of_Non_founder_CEO 
Total
Percentage_of_founder_CEO = Number_of_founder_CEO/ Total* 100
Percentage_of_Non_founder_CEO = 100- Percentage_of_founder_CEO

# %%
Percentage_of_founder_CEO
# Out:
# digit2_in
# 10           NaN
# 13           NaN
# 15     10.000000
# 16           NaN
# 20      0.000000
# 21           NaN
# 22      0.000000
# 23     23.076923
# 24      0.000000
# 25           NaN
# 26      9.677419
# 27      0.000000
# 28      0.000000
# 29     17.647059
# 30     56.250000
# 31           NaN
# 32           NaN
# 33     25.714286
# 34      0.000000
# 35     22.666667
# 36     40.000000
# 37      9.433962
# 38     46.875000
# 39      0.000000
# 40           NaN
# 42      0.000000
# 45    100.000000
# 48     36.363636
# 49    100.000000
# 50      0.000000
# 51      0.000000
# 52    100.000000
# 53     25.000000
# 54      0.000000
# 55      0.000000
# 56     36.585366
# 57           NaN
# 58      0.000000
# 59     11.428571
# 60      0.000000
# 61           NaN
# 62           NaN
# 63     14.285714
# 64           NaN
# 70      0.000000
# 72     40.000000
# 73     72.972973
# 75           NaN
# 78      0.000000
# 79           NaN
# 80           NaN
# 87           NaN
# ...

# %%
Percentage_of_Non_founder_CEO
# Out:
# digit2_in
# 10           NaN
# 13           NaN
# 15     90.000000
# 16           NaN
# 20    100.000000
# 21           NaN
# 22    100.000000
# 23     76.923077
# 24    100.000000
# 25           NaN
# 26     90.322581
# 27    100.000000
# 28    100.000000
# 29     82.352941
# 30     43.750000
# 31           NaN
# 32           NaN
# 33     74.285714
# 34    100.000000
# 35     77.333333
# 36     60.000000
# 37     90.566038
# 38     53.125000
# 39    100.000000
# 40           NaN
# 42    100.000000
# 45      0.000000
# 48     63.636364
# 49      0.000000
# 50    100.000000
# 51    100.000000
# 52      0.000000
# 53     75.000000
# 54    100.000000
# 55    100.000000
# 56     63.414634
# 57           NaN
# 58    100.000000
# 59     88.571429
# 60    100.000000
# 61           NaN
# 62           NaN
# 63     85.714286
# 64           NaN
# 70    100.000000
# 72     60.000000
# 73     27.027027
# 75           NaN
# 78    100.000000
# 79           NaN
# 80           NaN
# 87           NaN
# ...

# %%
pip install tabulate

# %%
from tabulate import tabulate

# %%
result = [Number_of_founder_CEO, Number_of_Non_founder_CEO, Percentage_of_founder_CEO]
result
# Out:
# [digit2_in
#  10     0
#  13     0
#  15     1
#  16     0
#  20     0
#  21     0
#  22     0
#  23     3
#  24     0
#  25     0
#  26     3
#  27     0
#  28     0
#  29     3
#  30    18
#  31     0
#  32     0
#  33     9
#  34     0
#  35    17
#  36    16
#  37     5
#  38    15
#  39     0
#  40     0
#  42     0
#  45     9
#  48     8
#  49     5
#  50     0
#  51     0
#  52     9
#  53     5
#  54     0
#  55     0
#  56    15
#  57     0
#  58     0
#  59     4
#  60     0
#  61     0
#  62     0
#  63     4
#  64     0
#  70     0
#  72     8
#  73    27
#  75     0
#  78     0
#  79     0
#  80     0
#  87     0
#  Name: founderCEO, dtype: int64, digit2_in
#  10     0
#  13     0
#  15     9
#  16     0
#  20    69
#  21     0
#  22    10
#  23    10
#  24    16
#  25     0
#  26    28
#  27    67
#  28    76
#  29    14
#  30    14
#  31     0
#  32     0
#  33    26
#  34    26
#  35    58
#  36    24
#  37    48
#  38    17
#  39    10
#  40     0
#  42     7
# ...

# %%
Percentage_of_Non_founder_CEO = 100- Percentage_of_founder_CEO
Percentage_of_Non_founder_CEO
# Out:
# digit2_in
# 10           NaN
# 13           NaN
# 15     90.000000
# 16           NaN
# 20    100.000000
# 21           NaN
# 22    100.000000
# 23     76.923077
# 24    100.000000
# 25           NaN
# 26     90.322581
# 27    100.000000
# 28    100.000000
# 29     82.352941
# 30     43.750000
# 31           NaN
# 32           NaN
# 33     74.285714
# 34    100.000000
# 35     77.333333
# 36     60.000000
# 37     90.566038
# 38     53.125000
# 39    100.000000
# 40           NaN
# 42    100.000000
# 45      0.000000
# 48     63.636364
# 49      0.000000
# 50    100.000000
# 51    100.000000
# 52      0.000000
# 53     75.000000
# 54    100.000000
# 55    100.000000
# 56     63.414634
# 57           NaN
# 58    100.000000
# 59     88.571429
# 60    100.000000
# 61           NaN
# 62           NaN
# 63     85.714286
# 64           NaN
# 70    100.000000
# 72     60.000000
# 73     27.027027
# 75           NaN
# 78    100.000000
# 79           NaN
# 80           NaN
# 87           NaN
# ...

# %%
df = pd.DataFrame(result)

# %%
# = [['First Name', 'Last Name', 'Age'], ['John', 'Smith', 39], ['Mary', 'Jane', 25], ['Jennifer', 'Doe', 28]]

# %%
Number_of_founder_CEO = total1
Number_of_founder_CEO

# %%
df.to_excel(r'table1.xlsx', index= False, header= True)

# %%
for firm in data['digit2_in']:
  familyfirm = sum(data['founderCEO'])
  print(familyfirm)
# Out:
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# ...

# %%
#data.describe()
#df.to_excel (r'C:\Users\Ron\Desktop\export_dataframe.xlsx', index = False, header=True)

# %%
import numpy as np
import pandas as pd
import stat
import matplotlib.pyplot as plt
# !pip install linearmodels

# Perform PooledOLS
from linearmodels import PooledOLS
import statsmodels.api as sm
from linearmodels import PanelOLS
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 9.5 MB 14.8 MB/s
# ...
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# ...

# %%
iv_1 = IV2SLS(dependent=data_2['LW'], exog=pd.concat([data_2['S'], h.drop(columns=['72'])], axis = 1), endog=data_2['IQ'], instruments=data_2[['MED', 'KWW', 'AGE', 'MRT']])  
res_2sls = iv_1.fit()
print(res_2sls)

# %%
data.head(20)
# Out:
#    ticker  year  meanagef  ...  NonFounderFamily     ln(Q)  ln(Asset)
# 0   9441B  1992       NaN  ...                 0  0.444055   8.579492
# 1   9441B  1993       NaN  ...                 0  0.442869   8.261449
# 2      AA  1992      95.0  ...                 0  0.211180   9.307748
# 3      AA  1993      95.0  ...                 0  0.202430   9.358493
# 4      AA  1994      95.0  ...                 0  0.268021   9.421670
# 5      AA  1995      95.0  ...                 0  0.308674   9.521011
# 6      AA  1996      95.0  ...                 0  0.398799   9.506727
# 7      AA  1997      95.0  ...                 0  0.452467   9.478121
# 8      AA  1998      95.0  ...                 0  0.364802   9.767811
# 9      AA  1999      95.0  ...                 0  0.881733   9.744843
# 10    AAL  1993       NaN  ...                 0  0.186961   7.935158
# 11   AAPL  1992      42.0  ...                 0  0.558428   8.348465
# ...

# %%
data.head()
# Out:
#   ticker  year  meanagef  ...  NonFounderFamily     ln(Q)  ln(Asset)
# 0  9441B  1992       NaN  ...                 0  0.444055   8.579492
# 1  9441B  1993       NaN  ...                 0  0.442869   8.261449
# 2     AA  1992      95.0  ...                 0  0.211180   9.307748
# 3     AA  1993      95.0  ...                 0  0.202430   9.358493
# 4     AA  1994      95.0  ...                 0  0.268021   9.421670
#
# [5 rows x 15 columns]

# %%
pd.get_dummies(data['year'])

# %%
 pd.get_dummies(data['digit2_in'])

# %%
#Create Dummy Variable
#type(data[['FamFirm']])

X=data[['FamFirm','bs_volatility','ln(Asset)','hightech']].join(pd.get_dummies(data['year'])).join(pd.get_dummies(data['digit2_in']))
X.head()
# Out:
#    FamFirm  bs_volatility  ln(Asset)  hightech  1992  ...  75  78  79  80  87
# 0        0          0.190   8.579492         0     1  ...   0   0   0   0   0
# 1        0          0.221   8.261449         0     0  ...   0   0   0   0   0
# 2        0          0.246   9.307748         0     1  ...   0   0   0   0   0
# 3        0          0.228   9.358493         0     0  ...   0   0   0   0   0
# 4        0          0.222   9.421670         0     0  ...   0   0   0   0   0
#
# [5 rows x 66 columns]

# %%
#Mutlivariate Analysis

# %%
#Column I
y = data['Q']
X=data[['FamFirm','bs_volatility','ln(Asset)','hightech']].join(pd.get_dummies(data['year'])).join(pd.get_dummies(data['digit2_in']))               
X = sm.add_constant(X)
model = sm.OLS(y,X)
results = model.fit()

#Print the regression coefficients
results.params
results.tvalues
R2 = print(results.rsquared)

print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-54-5d4bdb29d11f> in <module>()
#       3 X=data[['FamFirm','bs_volatility','ln(Asset)','hightech']].join(pd.get_dummies(data['year'])).join(pd.get_dummies(data['digit2_in']))
#       4 X = sm.add_constant(X)
# ----> 5 model = sm.OLS(y,X)
#       6 results = model.fit()
#       7
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     871                  **kwargs):
#     872         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#     875             self._init_keys.remove("weights")
#
# ...

# %%
#Column II

y = data['Q']
X=data[['FamFirm','bs_volatility','ln(Asset)','hightech']].join(pd.get_dummies(data['year'])).join(pd.get_dummies(data['digit2_in']))               
X = sm.add_constant(X)
model = sm.OLS(y,X)
results = model.fit(cov_type='HC3')


#Print the regression coefficients
results.params
results.tvalues
R2 = print(results.rsquared)

print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-43-82a5a50dd7d0> in <module>()
#       4 X=data[['FamFirm','bs_volatility','ln(Asset)','hightech']].join(pd.get_dummies(data['year'])).join(pd.get_dummies(data['digit2_in']))
#       5 X = sm.add_constant(X)
# ----> 6 model = sm.OLS(y,X)
#       7 results = model.fit(cov_type='HC3')
#       8
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     871                  **kwargs):
#     872         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#     875             self._init_keys.remove("weights")
#
# ...

# %%
#Column III
y = data['Q']
X=data[['founderCEO','bs_volatility','ln(Asset)','hightech']].join(pd.get_dummies(data['year'])).join(pd.get_dummies(data['digit2_in']))               
X = sm.add_constant(X)
model = sm.OLS(y,X)
results = model.fit()

#Print the regression coefficients
results.params
results.tvalues
R2 = print(results.rsquared)

print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-44-30fc076639d4> in <module>()
#       3 X=data[['founderCEO','bs_volatility','ln(Asset)','hightech']].join(pd.get_dummies(data['year'])).join(pd.get_dummies(data['digit2_in']))
#       4 X = sm.add_constant(X)
# ----> 5 model = sm.OLS(y,X)
#       6 results = model.fit()
#       7
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     871                  **kwargs):
#     872         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#     875             self._init_keys.remove("weights")
#
# ...

# %%
#Column IV
y = data['Q']
X=data[['NonFounderFamily','bs_volatility','ln(Asset)','hightech']].join(pd.get_dummies(data['year'])).join(pd.get_dummies(data['digit2_in']))               
X = sm.add_constant(X)
model = sm.OLS(y,X)
results = model.fit()

#Print the regression coefficients
results.params
results.tvalues
R2 = print(results.rsquared)

print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-45-ab371a73a749> in <module>()
#       3 X=data[['NonFounderFamily','bs_volatility','ln(Asset)','hightech']].join(pd.get_dummies(data['year'])).join(pd.get_dummies(data['digit2_in']))
#       4 X = sm.add_constant(X)
# ----> 5 model = sm.OLS(y,X)
#       6 results = model.fit()
#       7
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     871                  **kwargs):
#     872         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#     875             self._init_keys.remove("weights")
#
# ...

# %%
#Column V

y = data['roa']
X=data[['FamFirm','bs_volatility','ln(Asset)','hightech']].join(pd.get_dummies(data['year'])).join(pd.get_dummies(data['digit2_in']))               
X = sm.add_constant(X)
model = sm.OLS(y,X)
results = model.fit()

#Print the regression coefficients
results.params
results.tvalues
R2 = print(results.rsquared)

print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-46-4fd6c0ef2e4f> in <module>()
#       4 X=data[['FamFirm','bs_volatility','ln(Asset)','hightech']].join(pd.get_dummies(data['year'])).join(pd.get_dummies(data['digit2_in']))
#       5 X = sm.add_constant(X)
# ----> 6 model = sm.OLS(y,X)
#       7 results = model.fit()
#       8
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     871                  **kwargs):
#     872         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#     875             self._init_keys.remove("weights")
#
# ...

# %%
#Column VI
y = data['roa']
X=data[['founderCEO','bs_volatility','ln(Asset)','hightech']].join(pd.get_dummies(data['year'])).join(pd.get_dummies(data['digit2_in']))               
X = sm.add_constant(X)
model = sm.OLS(y,X)
results = model.fit()

#Print the regression coefficients
results.params
results.tvalues
R2 = print(results.rsquared)

print(results.summary())
# Out:
# 0.23157724849758843
#                             OLS Regression Results
# ...
# Dep. Variable:                    roa   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.190
# Method:                 Least Squares   F-statistic:                     5.604
# Date:                Mon, 26 Jul 2021   Prob (F-statistic):           5.41e-27
# Time:                        14:59:48   Log-Likelihood:                -2902.5
# No. Observations:                 922   AIC:                             5901.
# Df Residuals:                     874   BIC:                             6133.
# Df Model:                          47
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            13.2155      1.885      7.009      0.000       9.515      16.916
# ...

# %%
#Column VII
y = data['roa']
X=data[['NonFounderFamily','bs_volatility','ln(Asset)','hightech']].join(pd.get_dummies(data['year'])).join(pd.get_dummies(data['digit2_in']))               
X = sm.add_constant(X)
model = sm.OLS(y,X)
results = model.fit()

#Print the regression coefficients
results.params
results.tvalues
R2 = print(results.rsquared)

print(results.summary())
# Out:
# 0.23157724849758843
#                             OLS Regression Results
# ...
# Dep. Variable:                    roa   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.190
# Method:                 Least Squares   F-statistic:                     5.604
# Date:                Mon, 26 Jul 2021   Prob (F-statistic):           5.41e-27
# Time:                        15:00:45   Log-Likelihood:                -2902.5
# No. Observations:                 922   AIC:                             5901.
# Df Residuals:                     874   BIC:                             6133.
# Df Model:                          47
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               15.0800      1.985      7.595      0.000      11.183      18.977
# ...

# %%
#Column VIII, IX, X

#Eliminate nonfounderfam = 1 and re run above regresions

# %%
#Correcting for heteroskedascity 

y = data['Q']
X=data[['nonfounderfam','bs_volatility','lnasset','hightech','dummies','dummies']]               
X = sm.add_constant(X)
model = sm.OLS(y,X)
results = model.fit(cov_type ='HC3')

#Print the regression coefficients
results.params
results.tvalues
resutls.bse
results.t_test

print(results.summary())

# %%
#Part 5: Instrumental Variables
#Set Up Y variable

#Instrumental variables has correlation with the IV but not with the residuals. First step regress Inde Var on IV, to get predicted value. Second step to regress Dep Vari on predicted value.
#This is one way to deal with endogeneity.

 
#from statsmodels.sandbox.regression.gmm import IV2SLS
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Set up Exogeneous Variables

# %%
#Set up Instrumental Variables

# %%
#Run The Regression


#iv_1 = IV2SLS(exog=pd.concat([data['bs_volatility'], data['ln(Asset)'] , data['hightech']]), endog=(data['founderCEO']), instrument = data['meanagef']).fit()
#res_2sls = iv_1.fit()
#print(res_2sls)
#print(print(iv1.summary))


#resultIV.spec_hausman()
#Source: https://stats.stackexchange.com/questions/210696/how-to-interpret-hausman-test-results

# %%
iv = IV2SLS( exog= data[['bs_volatility', 'ln(Asset)', 'hightech']], endog = data['founderCEO'] , instrument = data['meanagef']).fit()

#print(iv.summary)

# %%
# !pip install linearmodels
from linearmodels import IV2SLS
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 4.2 MB/s
# ...
#      |████████████████████████████████| 9.5 MB 17.8 MB/s
# ...
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# ...

# %%
#Stag1
reg1 = sm.ols(exog,instruments).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-9f7219ce3f9e> in <module>()
#       1 #Stag1
# ----> 2 reg1 = sm.ols(exog,instruments).fit()
#
# NameError: name 'sm' is not defined

# %%
endog = data['founderCEO']

data['const'] = 1
data['const'] = 1
exog = pd.concat([data[['const', 'bs_volatility']], np.log(data['assets']),
               data['hightech'],pd.get_dummies(data['year']),pd.get_dummies(data['digit2_in'])], axis=1)



instruments = data['meanagef']
y = data['Q']

modeliv = IV2SLS(y, exog[['const', 'bs_volatility', 'assets', 'hightech']], endog, instruments).fit()
print(model)
# Out:
#                           IV-2SLS Estimation Summary
# ...
# Dep. Variable:                      Q   R-squared:                      0.0778
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.0706
# No. Observations:                 517   F-statistic:                    43.209
# Date:                Tue, Jul 27 2021   P-value (F-stat)                0.0000
# Time:                        10:33:06   Distribution:                  chi2(4)
# Cov. Estimator:                robust
#
#                                Parameter Estimates
# ...
#                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------
# const             1.2566     0.7845     1.6019     0.1092     -0.2809      2.7941
# bs_volatility    -0.5562     1.4373    -0.3870     0.6988     -3.3733      2.2609
# assets            0.0860     0.0635     1.3555     0.1753     -0.0384      0.2104
# ...

# %%
model.spec_hausman()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-57f47dcc399f> in <module>()
# ----> 1 model.spec_hausman()
#
# AttributeError: 'IVResults' object has no attribute 'spec_hausman'

# %%
modeliv.params
# Out:
# const            1.256586
# bs_volatility   -0.556192
# assets           0.086031
# hightech         0.764342
# founderCEO       1.225767
# Name: parameter, dtype: float64
